# %% [markdown]
# <a href="https://colab.research.google.com/github/VentureMikey/ALK2021BD/blob/main/28818_Mykhailo_Khaletskyi_Individual_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()


for fn in uploaded.keys():

  print('User uploaded file "{name}" with length {length} bytes'.format(

name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3bb73ac9-43e4-4b57-8332-3a8f4dcf091a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bb73ac9-43e4-4b57-8332-3a8f4dcf091a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-22-4db7c49b0247> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload()
#       4
#       5
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
#      73     if result['action'] != 'append':
#      74       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: RangeError: Maximum call stack size exceeded.

# %%
import pandas as pd
import numpy as np
import os

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import tree

# %%
Covid19= pd.read_csv (r'/content/Covid Dataset.csv')

# %%
Covid19.isna().sum()
# Out:
# Breathing Problem                          0
# Fever                                      0
# Dry Cough                                  0
# Sore throat                                0
# Running Nose                               0
# Asthma                                     0
# Chronic Lung Disease                       0
# Headache                                   0
# Heart Disease                              0
# Diabetes                                   0
# Hyper Tension                              0
# Fatigue                                    0
# Gastrointestinal                           0
# Abroad travel                              0
# Contact with COVID Patient                 0
# Attended Large Gathering                   0
# Visited Public Exposed Places              0
# Family working in Public Exposed Places    0
# Wearing Masks                              0
# Sanitization from Market                   0
# COVID-19                                   0
# dtype: int64

# %%
Covid19= pd.read_csv (r'/content/cardio_train.csv')

# %%
CARDIO= pd.read_csv (r'/content/cardio_train.csv')

# %%
Covid19= pd.read_csv (r'/content/Covid Dataset.csv')

# %%
CARDIO= pd.read_csv (r'/content/cardio_train1.csv')

# %%
Covid19.describe(include='all')
# Out:
#        Breathing Problem Fever  ... Sanitization from Market COVID-19
# count               5434  5434  ...                     5434     5434
# unique                 2     2  ...                        1        2
# top                  Yes   Yes  ...                       No      Yes
# freq                3620  4273  ...                     5434     4383
#
# [4 rows x 21 columns]

# %%
CARDIO.describe(include='all')
# Out:
#                  id           age  ...        active        cardio
# count  70000.000000  70000.000000  ...  70000.000000  70000.000000
# mean   49972.419900  19468.865814  ...      0.803729      0.499700
# std    28851.302323   2467.251667  ...      0.397179      0.500003
# min        0.000000  10798.000000  ...      0.000000      0.000000
# 25%    25006.750000  17664.000000  ...      1.000000      0.000000
# 50%    50001.500000  19703.000000  ...      1.000000      0.000000
# 75%    74889.250000  21327.000000  ...      1.000000      1.000000
# max    99999.000000  23713.000000  ...      1.000000      1.000000
#
# [8 rows x 13 columns]

# %%
Covid19.columns
# Out:
# Index(['Breathing Problem', 'Fever', 'Dry Cough', 'Sore throat',
#        'Running Nose', 'Asthma', 'Chronic Lung Disease', 'Headache',
#        'Heart Disease', 'Diabetes', 'Hyper Tension', 'Fatigue ',
#        'Gastrointestinal ', 'Abroad travel', 'Contact with COVID Patient',
#        'Attended Large Gathering', 'Visited Public Exposed Places',
#        'Family working in Public Exposed Places', 'Wearing Masks',
#        'Sanitization from Market', 'COVID-19'],
#       dtype='object')

# %%
CARDIO.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
Covid19[["Breathing Problem", "Fever", "Dry Cough", "Sore throat","Running Nose", "Asthma", "Chronic Lung Disease", "Headache","Heart Disease", "Diabetes", "Hyper Tension", "Fatigue ","Gastrointestinal ", "Abroad travel", "Contact with COVID Patient","Attended Large Gathering", "Visited Public Exposed Places","Family working in Public Exposed Places", "Wearing Masks","Sanitization from Market", "COVID-19"]].apply(lambda x: x.value_counts()).T.stack()
# Out:
# Breathing Problem                        No     1814.0
#                                          Yes    3620.0
# Fever                                    No     1161.0
#                                          Yes    4273.0
# Dry Cough                                No     1127.0
#                                          Yes    4307.0
# Sore throat                              No     1481.0
#                                          Yes    3953.0
# Running Nose                             No     2482.0
#                                          Yes    2952.0
# Asthma                                   No     2920.0
#                                          Yes    2514.0
# Chronic Lung Disease                     No     2869.0
#                                          Yes    2565.0
# Headache                                 No     2698.0
#                                          Yes    2736.0
# Heart Disease                            No     2911.0
#                                          Yes    2523.0
# Diabetes                                 No     2846.0
#                                          Yes    2588.0
# Hyper Tension                            No     2771.0
#                                          Yes    2663.0
# Fatigue                                  No     2613.0
#                                          Yes    2821.0
# Gastrointestinal                         No     2883.0
#                                          Yes    2551.0
# Abroad travel                            No     2983.0
#                                          Yes    2451.0
# Contact with COVID Patient               No     2708.0
#                                          Yes    2726.0
# Attended Large Gathering                 No     2924.0
#                                          Yes    2510.0
# Visited Public Exposed Places            No     2614.0
#                                          Yes    2820.0
# Family working in Public Exposed Places  No     3172.0
#                                          Yes    2262.0
# Wearing Masks                            No     5434.0
# Sanitization from Market                 No     5434.0
# COVID-19                                 No     1051.0
#                                          Yes    4383.0
# dtype: float64

# %%
CARDIO[["id", "age", "gender", "height", "weight", "ap_hi", "ap_lo", "cholesterol", "gluc", "smoke", "alco", "active", "cardio"]].apply(lambda x: x.value_counts()).T.stack()
# Out:
# id      0.0        1.0
#         1.0        1.0
#         2.0        1.0
#         3.0        1.0
#         4.0        1.0
#                 ...
# alco    1.0     3764.0
# active  0.0    13739.0
#         1.0    56261.0
# cardio  0.0    35021.0
#         1.0    34979.0
# Length: 78798, dtype: float64

# %%
Covid19=Covid19.drop('Wearing Masks',axis=1)
Covid19=Covid19.drop('Sanitization from Market',axis=1)

# %%
Covid19
# Out:
#      Breathing Problem Fever  ... Family working in Public Exposed Places COVID-19
# 0                  Yes   Yes  ...                                     Yes      Yes
# 1                  Yes   Yes  ...                                      No      Yes
# 2                  Yes   Yes  ...                                      No      Yes
# 3                  Yes   Yes  ...                                      No      Yes
# 4                  Yes   Yes  ...                                      No      Yes
# ...                ...   ...  ...                                     ...      ...
# 5429               Yes   Yes  ...                                      No      Yes
# 5430               Yes   Yes  ...                                      No      Yes
# 5431               Yes   Yes  ...                                      No       No
# 5432               Yes   Yes  ...                                      No       No
# 5433               Yes   Yes  ...                                      No       No
#
# [5434 rows x 19 columns]

# %%
CARDIO
# Out:
#           id    age  gender  height  weight  ...  gluc  smoke  alco  active  cardio
# 0          0  18393       2     168    62.0  ...     1      0     0       1       0
# 1          1  20228       1     156    85.0  ...     1      0     0       1       1
# 2          2  18857       1     165    64.0  ...     1      0     0       0       1
# 3          3  17623       2     169    82.0  ...     1      0     0       1       1
# 4          4  17474       1     156    56.0  ...     1      0     0       0       0
# ...      ...    ...     ...     ...     ...  ...   ...    ...   ...     ...     ...
# 69995  99993  19240       2     168    76.0  ...     1      1     0       1       0
# 69996  99995  22601       1     158   126.0  ...     2      0     0       1       1
# 69997  99996  19066       2     183   105.0  ...     1      0     1       0       1
# 69998  99998  22431       1     163    72.0  ...     2      0     0       0       1
# 69999  99999  20540       1     170    72.0  ...     1      0     0       1       0
#
# [70000 rows x 13 columns]

# %%
CARDIO=CARDIO.drop('id',axis=1)

# %%
CARDIO
# Out:
#          age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0      18393       2     168    62.0    110  ...     1      0     0       1       0
# 1      20228       1     156    85.0    140  ...     1      0     0       1       1
# 2      18857       1     165    64.0    130  ...     1      0     0       0       1
# 3      17623       2     169    82.0    150  ...     1      0     0       1       1
# 4      17474       1     156    56.0    100  ...     1      0     0       0       0
# ...      ...     ...     ...     ...    ...  ...   ...    ...   ...     ...     ...
# 69995  19240       2     168    76.0    120  ...     1      1     0       1       0
# 69996  22601       1     158   126.0    140  ...     2      0     0       1       1
# 69997  19066       2     183   105.0    180  ...     1      0     1       0       1
# 69998  22431       1     163    72.0    135  ...     2      0     0       0       1
# 69999  20540       1     170    72.0    120  ...     1      0     0       1       0
#
# [70000 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
e=LabelEncoder()

# %%
Covid19['Breathing Problem']=e.fit_transform(Covid19['Breathing Problem'])
Covid19['Fever']=e.fit_transform(Covid19['Fever'])
Covid19['Dry Cough']=e.fit_transform(Covid19['Dry Cough'])
Covid19['Sore throat']=e.fit_transform(Covid19['Sore throat'])
Covid19['Running Nose']=e.fit_transform(Covid19['Running Nose'])
Covid19['Asthma']=e.fit_transform(Covid19['Asthma'])
Covid19['Chronic Lung Disease']=e.fit_transform(Covid19['Chronic Lung Disease'])
Covid19['Headache']=e.fit_transform(Covid19['Headache'])
Covid19['Heart Disease']=e.fit_transform(Covid19['Heart Disease'])
Covid19['Diabetes']=e.fit_transform(Covid19['Diabetes'])
Covid19['Hyper Tension']=e.fit_transform(Covid19['Hyper Tension'])
Covid19['Abroad travel']=e.fit_transform(Covid19['Abroad travel'])
Covid19['Contact with COVID Patient']=e.fit_transform(Covid19['Contact with COVID Patient'])
Covid19['Attended Large Gathering']=e.fit_transform(Covid19['Attended Large Gathering'])
Covid19['Visited Public Exposed Places']=e.fit_transform(Covid19['Visited Public Exposed Places'])
Covid19['Family working in Public Exposed Places']=e.fit_transform(Covid19['Family working in Public Exposed Places'])
Covid19['COVID-19']=e.fit_transform(Covid19['COVID-19'])
Covid19['Dry Cough']=e.fit_transform(Covid19['Dry Cough'])
Covid19['Sore throat']=e.fit_transform(Covid19['Sore throat'])
Covid19['Gastrointestinal ']=e.fit_transform(Covid19['Gastrointestinal '])
Covid19['Fatigue ']=e.fit_transform(Covid19['Fatigue '])

# %%
corr=Covid19.corr()
corr.style.background_gradient(cmap='coolwarm',axis=None)
# Out:
# <style  type="text/css" >
# #T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row6_col6,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row7_col7,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row8_col8,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row11_col11,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row12_col12,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col13,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row14_col14,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row17_col17,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row18_col18{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col18,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row18_col5{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row17_col18,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row18_col17{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row7_col11,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row11_col7{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col1{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col6,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row6_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col7,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col17,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row6_col14,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row7_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row12_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row14_col6,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col12,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row17_col4{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col8,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col12,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row8_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row12_col0{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row6_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row7_col13,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col6,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col7{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col11,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col8,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col9,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col14,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row8_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row8_col12,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row9_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row11_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row12_col8,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row14_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col13,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col13{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col14,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row14_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col3{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col0{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col15,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col7,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col13,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row7_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col13{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col17,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row17_col0{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row0_col18,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col18,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row18_col0,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row18_col13{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col13,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col14,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row13_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row14_col2{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col1{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row1_col4,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row2_col10,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row3_col5,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row4_col1,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row5_col3,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row10_col2,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row15_col16,#T_32dd16e2_c706_11eb_bb83_0242ac1c0002row16_col15{
#             background-color:  #89acfd;

# %%
CARDIO['gender']=e.fit_transform(CARDIO['gender'])
CARDIO['cholesterol']=e.fit_transform(CARDIO['cholesterol'])
CARDIO['gluc']=e.fit_transform(CARDIO['gluc'])
CARDIO['smoke']=e.fit_transform(CARDIO['smoke'])
CARDIO['alco']=e.fit_transform(CARDIO['alco'])
CARDIO['active']=e.fit_transform(CARDIO['active'])
CARDIO['cardio']=e.fit_transform(CARDIO['cardio'])

# %%
corr=CARDIO.corr()
corr.style.background_gradient(cmap='coolwarm',axis=None)
# Out:
# <style  type="text/css" >
# #T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col0,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col3,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col3,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col0,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col4{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col0,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col5{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col0,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col4{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col0{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col0{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col0{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col0,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row0_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col0{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col1{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col3,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col1{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col5{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col4{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col10{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col1,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col8{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col1{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row1_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col3,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col2{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col2{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row8_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col9,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col2{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row2_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col10,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row9_col11,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col2,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row10_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row11_col9{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col4,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row4_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col5,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row5_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col6,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row6_col3{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col7,#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row7_col3{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_af7d3dda_c706_11eb_bb83_0242ac1c0002row3_col8,#T_af7d3dda_c706_11eb_bb83_0242ac1c00
